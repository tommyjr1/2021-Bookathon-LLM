# %%
import numpy as np
import pandas as pd

# %%
book = pd.read_excel("/content/drive/MyDrive/2021/2021 데컬코마니 북커톤/data/2021 독서리뷰.xlsx")
book
# Out:
#                                                   글 내용
# 0    2년 전에 동아리 활동으로 읽었던 기억이 나서 올해도 가기 전에 한 번 읽어보면서 ...
# 1    과거에 사람들에게 많이 읽혔던 문학과 현대에 사람들에게 많이 읽히는 문학은 당연하게...
# 2    ...결국에는 유예된 복수의 그림자가 다음 몇 세대에 걸쳐 계속 드리워지게 되었다....
# 3    토크빌은 미국의 민주주의를 매우 긍정적으로 평가했다. 당시 미국과 프랑스의 사회적 ...
# 4    &lt;찰스 다윈에게 보내는 편지&gt;자연선택이라는\n기제를 중심으로 진화론을 설...
# ..                                                 ...
# 597  얼마전에 사피엔스를 읽었다. 아마 책을 읽은 대부분의 사람들이 재밌어 할만한 내용이...
# 598  읽기전에- 이 글은 짧은 소설입니다. 이 글에서 등장하는 인물과 사건은 모두 실제와...
# 599  읽기 전에- 이 글은 2020년에 쓴 글입니다. 본문 중에 나오는 표현이 2021년...
# 600  아직도 어린이병에 걸려있는 당신에게\n\n시험기간을 보내면서 1학년 때 교양수업 교...
# 601  원래 내 것이었던 것들을 되찾는 섬뜩한 여정을 다루고 있는 책이다. 여동생인(줄 알...
#
# [602 rows x 1 columns]

# %%
sample = book['글 내용'][2]

# %%
type(sample)
# Out:
# str

# %%
# 행 하나씩 txt로 저장
for i in range(len(book)):
  content = str(book['글 내용'][i])
  file = open("/content/drive/MyDrive/2021/2021 데컬코마니 북커톤/data/2021 독서리뷰/"+ str(i) +".txt", "w")
  file.write(content)
  file.close()

# %%
# 2019-2020
book = pd.read_excel("/content/drive/MyDrive/2021/2021 데컬코마니 북커톤/data/2019-2020 독서리뷰-수정.xlsx")
# 행 하나씩 txt로 저장
for i in range(len(book)):
  content = str(book['글 내용'][i])
  file = open("/content/drive/MyDrive/2021/2021 데컬코마니 북커톤/data/2019-2020 독서리뷰/"+ str(i) +".txt", "w")
  file.write(content)
  file.close()

# %%
# 2018
book = pd.read_excel("/content/drive/MyDrive/2021/2021 데컬코마니 북커톤/data/2018 독서리뷰-수정.xlsx")
book.dropna(axis=0, inplace=True)
book.reset_index(drop=True, inplace=True)
cnt = 0
for i in range(len(book)):
  cnt+=1
  content = str(book['글 내용'][i])
  file = open("/content/drive/MyDrive/2021/2021 데컬코마니 북커톤/data/2018 독서리뷰/"+ str(i) +".txt", "w")
  file.write(content)
  file.close()

print(cnt)
# Out:
# 1467

# %%
# 2017
book = pd.read_excel("/content/drive/MyDrive/2021/2021 데컬코마니 북커톤/data/2017 독서리뷰-수정.xlsx")
for i in range(len(book)):
  content = str(book['글 내용'][i])
  file = open("/content/drive/MyDrive/2021/2021 데컬코마니 북커톤/data/2017 독서리뷰/"+ str(i) +".txt", "w")
  file.write(content)
  file.close()

# %%
# 2016
book = pd.read_excel("/content/drive/MyDrive/2021/2021 데컬코마니 북커톤/data/2016 독서리뷰-수정.xlsx")
book
# Out:
#                                                    글 내용
# 0     아빠가 평소에 책을 읽는 것을 매우 좋아하셔서, 책을 먼저 찾아 읽는 습관이 되어 ...
# 1     인권이란 인간으로서 누리는 당연한 권리인 자연권으로서 오랜 시간을 지나면서 서서히 ...
# 2     맹자의 여러 구절이 있지만 그중에서도 모든 잘못을 스스로에게서 돌이켜 구하라라는 ‘...
# 3     핑거스미스는 매우 매혹적인 소설이다. 어떤 사람은 '동성애 소설이다.' '19세기 ...
# 4     내가 과학철학이라는 분야를 처음 알게 된 것은 "장하석의 과학, 철학을 만나다."라...
# ...                                                 ...
# 1938  대한민국 사람이라면 흔히 ‘취미’란에 ‘음악 감상’이라 적곤 한다. 나 역시 나의 ...
# 1939  [교수 학생 책읽기] 2012 김지명학교를 걷다 우연히 교수 학생 책읽기라는 프로그...
# 1940                                                NaN
# 1941  '박사가 사랑한 수식'\n\n고등학교 시절 영화로 이 박사가 사랑한 수식을 보았다....
# 1942  제목: ‘복종’, 현대인의 이기적 삶에 날리는 경고‘복종’이란 책에 대한 설명을 처...
#
# [1943 rows x 1 columns]

# %%
book.dropna(axis=0, inplace=True)
book.reset_index(drop=True, inplace=True)
book
# Out:
#                                                    글 내용
# 0     아빠가 평소에 책을 읽는 것을 매우 좋아하셔서, 책을 먼저 찾아 읽는 습관이 되어 ...
# 1     인권이란 인간으로서 누리는 당연한 권리인 자연권으로서 오랜 시간을 지나면서 서서히 ...
# 2     맹자의 여러 구절이 있지만 그중에서도 모든 잘못을 스스로에게서 돌이켜 구하라라는 ‘...
# 3     핑거스미스는 매우 매혹적인 소설이다. 어떤 사람은 '동성애 소설이다.' '19세기 ...
# 4     내가 과학철학이라는 분야를 처음 알게 된 것은 "장하석의 과학, 철학을 만나다."라...
# ...                                                 ...
# 1931  “태도나 행동이 건방지거나 거만함, 공정하지 못하고 한쪽으로 치우친 생각.” 오만과...
# 1932  대한민국 사람이라면 흔히 ‘취미’란에 ‘음악 감상’이라 적곤 한다. 나 역시 나의 ...
# 1933  [교수 학생 책읽기] 2012 김지명학교를 걷다 우연히 교수 학생 책읽기라는 프로그...
# 1934  '박사가 사랑한 수식'\n\n고등학교 시절 영화로 이 박사가 사랑한 수식을 보았다....
# 1935  제목: ‘복종’, 현대인의 이기적 삶에 날리는 경고‘복종’이란 책에 대한 설명을 처...
#
# [1936 rows x 1 columns]

# %%
cnt = 0
for i in range(len(book)):
  cnt+=1
  content = str(book['글 내용'][i])
  file = open("/content/drive/MyDrive/2021/2021 데컬코마니 북커톤/data/2016 독서리뷰/"+ str(i) +".txt", "w")
  file.write(content)
  file.close()

print(cnt +"개 파일 저장")

# %%
# 2015 한번에 하기
book = pd.read_excel("/content/drive/MyDrive/2021/2021 데컬코마니 북커톤/data/2015 독서리뷰-수정.xlsx")
book.dropna(axis=0, inplace=True)
book.reset_index(drop=True, inplace=True)
cnt = 0
for i in range(len(book)):
  cnt+=1
  content = str(book['글 내용'][i])
  file = open("/content/drive/MyDrive/2021/2021 데컬코마니 북커톤/data/201 독서리뷰/"+ str(i) +".txt", "w")
  file.write(content)
  file.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-3eabf4e1d983> in <module>()
#      11   file.close()
#      12
# ---> 13 print(cnt +"개 파일 저장")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
